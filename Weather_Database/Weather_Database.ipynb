# %%
#Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e0764f8e3bbd8471a2c638a8b4924c7f

# %%
#Create a set of random latitude and logitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
#Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 753

# %%
cities
# Out:
# ['hithadhoo',
#  'auki',
#  'punta arenas',
#  'dekar',
#  'hermanus',
#  'port elizabeth',
#  'rikitea',
#  'ca mau',
#  'belushya guba',
#  'manado',
#  'san patricio',
#  'barentsburg',
#  'jenison',
#  'mataura',
#  'lang son',
#  'beringovskiy',
#  'port alfred',
#  'busselton',
#  'cidreira',
#  'kapaa',
#  'pangai',
#  'bluff',
#  'namatanai',
#  'mattru',
#  'hamilton',
#  'upernavik',
#  'avarua',
#  'cape town',
#  'ushuaia',
#  'dingle',
#  'puerto ayora',
#  'provideniya',
#  'albany',
#  'alenquer',
#  'asau',
#  'qaanaaq',
#  'moron',
#  'klaksvik',
#  'ponta do sol',
#  'sao filipe',
#  'saint-philippe',
#  'ilulissat',
#  'tuktoyaktuk',
#  'east london',
#  'zeya',
#  'alta floresta',
#  'verkhnevilyuysk',
#  'freeport',
#  'kuhdasht',
#  'bethel',
#  'hilo',
#  'yuzhno-yeniseyskiy',
#  'comodoro rivadavia',
#  'vila franca do campo',
#  'zarubino',
#  'taolanaro',
#  'saint george',
#  'pskov',
#  'attawapiskat',
#  'umzimvubu',
#  'touros',
#  'yar-sale',
#  'calvinia',
#  'kozhva',
#  'guekedou',
#  'pochutla',
#  'salalah',
#  'lasa',
#  'havre-saint-pierre',
#  'aksarka',
#  'tabou',
#  'charters towers',
#  'amapa',
#  'vardo',
#  'waslala',
#  'longyearbyen',
#  'sidney',
#  'tramagal',
#  'ostrovnoy',
#  'necochea',
#  'barrow',
#  'regina',
#  'lagoa',
#  'emerald',
#  'yulara',
#  'nikki',
#  'victoria',
#  'portland',
#  'dikson',
#  'bengkulu',
#  'vaitape',
#  'jiddah',
#  'mega',
#  'puerto madryn',
#  'illoqqortoormiut',
#  'roald',
#  'altamira',
#  'adwa',
#  'viedma',
#  'plouzane',
#  'ust-koksa',
#  'samana',
#  'warrington',
#  'new norfolk',
#  'honningsvag',
#  'nguiu',
#  'ylivieska',
#  'kavieng',
#  'ajaccio',
#  'chokurdakh',
#  'cururupu',
#  'wattegama',
#  'vaini',
#  'arraial do cabo',
#  'tazovskiy',
#  'mehamn',
#  'namibe',
#  'cairns',
#  'grand river south east',
#  'nuevo progreso',
#  'kasongo',
#  'maloy',
#  'kodiak',
#  'dzhebariki-khaya',
#  'datia',
#  'kirakira',
#  'saskylakh',
#  'samalkha',
#  'carnarvon',
#  'yellowknife',
#  'florianopolis',
#  'praia da vitoria',
#  'thinadhoo',
#  'morro bay',
#  'chihuahua',
#  'puerto montt',
#  'coihaique',
#  'sitka',
#  'kuche',
#  'airai',
#  'karratha',
#  'khatanga',
#  'caravelas',
#  'changli',
#  'ginda',
#  'atar',
#  'nikolskoye',
#  'chuy',
#  'bredasdorp',
#  'cockburn town',
#  'prachuap khiri khan',
#  'savalou',
#  'teruel',
#  'atuona',
#  'talnakh',
#  'aklavik',
#  'plettenberg bay',
#  'hit',
#  'jamestown',
#  'ribeira grande',
#  'mandalgovi',
#  'chumikan',
#  'tahta',
#  'cabo san lucas',
#  'constitucion',
#  'ancud',
#  'nador',
#  'butaritari',
#  'rawson',
#  'glyadyanskoye',
#  'mys shmidta',
#  'lebu',
#  'mogadishu',
#  'port blair',
#  'itarema',
#  'baculin',
#  'amberley',
#  'guapore',
#  'platteville',
#  'evensk',
#  'codrington',
#  'zheleznodorozhnyy',
#  'krasnoye',
#  'quilali',
#  'tukrah',
#  'louisbourg',
#  'saint-joseph',
#  'vaitupu',
#  'kamenskoye',
#  'felanitx',
#  'gulf gate estates',
#  'buala',
#  'kudahuvadhoo',
#  'kirkwall',
#  'hobart',
#  'inuvik',
#  'amderma',
#  'seoul',
#  'terrace',
#  'mar del plata',
#  'sebinkarahisar',
#  'ahipara',
#  'saint-ambroise',
#  'batagay-alyta',
#  'machali',
#  'vao',
#  'warri',
#  'mildura',
#  'lokosovo',
#  'mount gambier',
#  'qaqortoq',
#  'lata',
#  'imbituba',
#  'pauini',
#  'aktau',
#  'mayuge',
#  'richards bay',
#  'guntur',
#  'bilma',
#  'melilla',
#  'cherskiy',
#  'cooma',
#  'vestmannaeyjar',
#  'longlac',
#  'carpentras',
#  'tiksi',
#  'clyde river',
#  'kruisfontein',
#  'fond du lac',
#  'nanortalik',
#  'bambanglipuro',
#  'maiduguri',
#  'isangel',
#  'sergeyevka',
#  'anadyr',
#  'kahului',
#  'mitu',
#  'kaeo',
#  'puerto gaitan',
#  'hambantota',
#  'jiwani',
#  'mareeba',
#  'sentyabrskiy',
#  'malakal',
#  'beloha',
#  'hasaki',
#  'sur',
#  'solnechnyy',
#  'tasiilaq',
#  'guerrero negro',
#  'dergaon',
#  'thompson',
#  'petatlan',
#  'quatre cocos',
#  'biak',
#  'gamba',
#  'cheuskiny',
#  'port hedland',
#  'bathsheba',
#  'esmeralda',
#  'abu kamal',
#  'mahebourg',
#  'grindavik',
#  'tuatapere',
#  'veraval',
#  'kaitangata',
#  'vila',
#  'souillac',
#  'narsaq',
#  'alice springs',
#  'jiuquan',
#  'kerman',
#  'samarai',
#  'westport',
#  'labutta',
#  'orsha',
#  'kloulklubed',
#  'rio gallegos',
#  'port-gentil',
#  'bokajan',
#  'esperance',
#  'umarkot',
#  'los llanos de aridane',
#  'dawlatabad',
#  'mirador',
#  'chipata',
#  'norman wells',
#  'puri',
#  'tucurui',
#  'pangoa',
#  'brewster',
#  'santa lucia',
#  'xining',
#  'padang',
#  'yangshe',
#  'outjo',
#  'chagda',
#  'kamenka',
#  'pervomayskiy',
#  'balgazyn',
#  'west lafayette',
#  'young',
#  'pemangkat',
#  'grand gaube',
#  'monroe',
#  'quesnel',
#  'jalu',
#  'fairbanks',
#  'geraldton',
#  'jizan',
#  'koumac',
#  'itaituba',
#  'poum',
#  'qostanay',
#  'meyungs',
#  'mount isa',
#  'soskovo',
#  'opuwo',
#  'leningradskiy',
#  'khao yoi',
#  'samalaeulu',
#  'utete',
#  'tabiauea',
#  'mudyuga',
#  'watsa',
#  'maraa',
#  'qandahar',
#  'colares',
#  'odienne',
#  'fortuna',
#  'samusu',
#  'seymchan',
#  'isla vista',
#  'san rafael',
#  'asfi',
#  'saldanha',
#  'maldonado',
#  'nakhodka',
#  'ino',
#  'georgetown',
#  'hami',
#  'palmer',
#  'darhan',
#  'buraydah',
#  'matamoros',
#  'sao felix do xingu',
#  'erzin',
#  'phayao',
#  'severo-kurilsk',
#  'lakes entrance',
#  'kitsuki',
#  'sarakhs',
#  'shimoda',
#  'mae hong son',
#  'brigantine',
#  'sampit',
#  'tumannyy',
#  'sabang',
#  'marcona',
#  'sretensk',
#  'high level',
#  'buon me thuot',
#  'campbell river',
#  'hay river',
#  'rawannawi',
#  'ales',
#  'tsihombe',
#  'neiafu',
#  'oksfjord',
#  'axim',
#  'belmonte',
#  'palabuhanratu',
#  'kiunga',
#  'vangaindrano',
#  'ulaangom',
#  'tingrela',
#  'artyk',
#  'pisco',
#  'bud',
#  'farafangana',
#  'linjiang',
#  'castro',
#  'toktogul',
#  'pevek',
#  'tyukhtet',
#  'ustye',
#  'sao miguel do araguaia',
#  'wanxian',
#  'nome',
#  'florenville',
#  'karmala',
#  'chapais',
#  'college',
#  'ayotzintepec',
#  'kaka',
#  'sofiysk',
#  'sar-e pul',
#  'torbay',
#  'kargasok',
#  'nyrob',
#  'pokrovsk',
#  'ust-tsilma',
#  'sabha',
#  'purpe',
#  'yinchuan',
#  'nizwa',
#  'murdochville',
#  'hunterville',
#  'xai-xai',
#  'bubaque',
#  'dandong',
#  'taoudenni',
#  'ihosy',
#  'kitui',
#  'arinos',
#  'dzhusaly',
#  'jiquinlaca',
#  'rakhya',
#  'valparaiso',
#  'turkmenabat',
#  'bayburt',
#  'salima',
#  'jibuti',
#  'tomari',
#  'mato verde',
#  'pizarro',
#  'aklera',
#  'henties bay',
#  'komsomolskiy',
#  'redmond',
#  'janakkala',
#  'umm kaddadah',
#  'tateyama',
#  'arlit',
#  'stornoway',
#  'ouadda',
#  'houlton',
#  'zhangye',
#  'dolbeau',
#  'panuco',
#  'tucumcari',
#  'luba',
#  'lolua',
#  'havoysund',
#  'kununurra',
#  'ngukurr',
#  'avera',
#  'faanui',
#  'tuban',
#  'ipixuna',
#  'saint-pierre',
#  'lompoc',
#  'afrikanda',
#  'tiznit',
#  'vershino-darasunskiy',
#  'barra do garcas',
#  'tiarei',
#  'fuerte olimpo',
#  'kisangani',
#  'awjilah',
#  'the valley',
#  'wanaka',
#  'tighnabruaich',
#  'pampa',
#  'juneau',
#  'gat',
#  'porbandar',
#  'dhidhdhoo',
#  'kayerkan',
#  'sakakah',
#  'chongwe',
#  'bocas del toro',
#  'tungor',
#  'toliary',
#  'otradnoye',
#  'san cristobal',
#  'ust-nera',
#  'robertsport',
#  'nizhneyansk',
#  'piracanjuba',
#  'tura',
#  'swellendam',
#  'iqaluit',
#  'pangkalanbuun',
#  'nemuro',
#  'paamiut',
#  'salto',
#  'vanavara',
#  'semirom',
#  'ballina',
#  'saint-augustin',
#  'lavrentiya',
#  'portobelo',
#  'haines junction',
#  'keflavik',
#  'vrangel',
#  'novoilinsk',
#  'sao jose da coroa grande',
#  'big spring',
#  'taltal',
#  'cochrane',
#  'tapaua',
#  'jimenez',
#  'port augusta',
#  'onega',
#  'lubao',
#  'akdepe',
#  'bolobo',
#  'olafsvik',
#  'beeville',
#  'sambava',
#  'morondava',
#  'takaka',
#  'maracaibo',
#  'mabaruma',
#  'northview',
#  'toccoa',
#  'oriximina',
#  'ploemeur',
#  'ulladulla',
#  'palmerston',
#  'natchez',
#  'bandarbeyla',
#  'maceio',
#  'tautira',
#  'sibu',
#  'hofn',
#  'hachinohe',
#  'shingu',
#  'gogapur',
#  'petropavlovskoye',
#  'alofi',
#  'sokolo',
#  'maniitsoq',
#  'leopold',
#  'cagayan de tawi-tawi',
#  'bairiki',
#  'bambous virieux',
#  'meulaboh',
#  'manhumirim',
#  'te anau',
#  'dengzhou',
#  'idlib',
#  'shestakovo',
#  'oktyabrskoye',
#  'hua hin',
#  'ajdabiya',
#  'labuhan',
#  'gayny',
#  'broome',
#  'knysna',
#  'hobyo',
#  'yingzhong',
#  'ponta delgada',
#  'bargal',
#  'rumuruti',
#  'motygino',
#  'muzhi',
#  'kysyl-syr',
#  'doha',
#  'narva-joesuu',
#  'saleaula',
#  'moindou',
#  'yabelo',
#  'dakar',
#  'manaure',
#  'vila velha',
#  'madras',
#  'sukumo',
#  'placido de castro',
#  'dali',
#  'gizo',
#  'fomboni',
#  'krasnoselkup',
#  'dongobesh',
#  'panacan',
#  'shumskiy',
#  'voh',
#  'coahuayana',
#  'cabedelo',
#  'san jeronimo',
#  'esmeraldas',
#  'nago',
#  'balabac',
#  'hualmay',
#  'athabasca',
#  'santa vitoria do palmar',
#  'papar',
#  'pafos',
#  'hun',
#  'bendigo',
#  'natal',
#  'kimbe',
#  'point pedro',
#  'lubumbashi',
#  'nouadhibou',
#  'pacific grove',
#  'yuxia',
#  'okhotsk',
#  'orsk',
#  'wahran',
#  'farmington',
#  'charlottetown',
#  'campoverde',
#  'ubinskoye',
#  'oranjestad',
#  'chauk',
#  'juifang',
#  'shakawe',
#  'pangnirtung',
#  'tawkar',
#  'blue island',
#  'bykov',
#  'bermeo',
#  'muisne',
#  'rungata',
#  'manono',
#  'standerton',
#  'ituni',
#  'harrison',
#  'acapulco',
#  'lysyanka',
#  'sakaiminato',
#  'alizai',
#  'lerwick',
#  'kita',
#  'ladyzhyn',
#  'shakhtinsk',
#  'khandbari',
#  'talaya',
#  'contramaestre',
#  'woodward',
#  'andenes',
#  'kuandian',
#  'egvekinot',
#  'meadow lake',
#  'utiroa',
#  'tsalka',
#  'mankono',
#  'shiloh',
#  'flinders',
#  'strai',
#  'lazaro cardenas',
#  'cartagena del chaira',
#  'inzer',
#  'toora-khem',
#  'ternate',
#  'creel',
#  'tselinnoye',
#  'copiapo',
#  'maragogi',
#  'coquimbo',
#  'cayenne',
#  'huajuapan',
#  'kiruna',
#  'miracatu',
#  'la ronge',
#  'mbaiki',
#  'bitung',
#  'springbok',
#  'kupang',
#  'sorvag',
#  'ust-kan',
#  'surgut',
#  'khor',
#  'diffa',
#  'belaya gora',
#  'penzance',
#  'lorengau',
#  'huilong',
#  'mora',
#  'xinqing',
#  'barcelona',
#  'spornoye',
#  'dibaya',
#  'nantucket',
#  'shcholkine',
#  'dawei',
#  'weymouth',
#  'tommot',
#  'american canyon',
#  'yerbogachen',
#  'sayville',
#  'dvinskoy',
#  'bundaberg',
#  'alugan',
#  'oyonnax',
#  'paita',
#  'montepuez',
#  'bilibino',
#  'grafton',
#  'kedrovyy',
#  'moranbah',
#  'taga',
#  'kijang',
#  'laguna',
#  'daru',
#  'gillette',
#  'malanje',
#  'mantua',
#  'fort myers beach',
#  'najran',
#  'preobrazheniye',
#  'malindi',
#  'katiola',
#  'killybegs',
#  'half moon bay',
#  'shenxian',
#  'ayorou',
#  'tambacounda',
#  'ewa beach',
#  'mucurapo',
#  'morant bay',
#  'paysandu',
#  'kasongo-lunda',
#  'broken hill',
#  'kamloops',
#  'bahia honda',
#  'celestun',
#  'musoma',
#  'rudarpur',
#  'puerto madero',
#  'husavik',
#  'whitianga',
#  'chopinzinho',
#  'ranong',
#  'markova',
#  'arman',
#  'marienburg',
#  'berlevag',
#  'ugoofaaru',
#  'carinhanha',
#  'port macquarie',
#  'port hardy',
#  'gisborne',
#  'ati',
#  'ciudad bolivar',
#  'weligama',
#  'villa carlos paz',
#  'katsuura',
#  'kuznechnoye',
#  'oranjemund',
#  'xiangdong',
#  'san vicente',
#  'demba',
#  'balagansk',
#  'praia',
#  'sozopol',
#  'mackay',
#  'sobolevo',
#  'aldama',
#  'bibiani',
#  'slave lake']

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hithadhoo
# Processing Record 2 of Set 1 | auki
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | dekar
# Processing Record 5 of Set 1 | hermanus
# Processing Record 6 of Set 1 | port elizabeth
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | ca mau
# Processing Record 9 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 1 | manado
# Processing Record 11 of Set 1 | san patricio
# Processing Record 12 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 1 | jenison
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | lang son
# Processing Record 16 of Set 1 | beringovskiy
# Processing Record 17 of Set 1 | port alfred
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | cidreira
# Processing Record 20 of Set 1 | kapaa
# Processing Record 21 of Set 1 | pangai
# Processing Record 22 of Set 1 | bluff
# Processing Record 23 of Set 1 | namatanai
# Processing Record 24 of Set 1 | mattru
# Processing Record 25 of Set 1 | hamilton
# Processing Record 26 of Set 1 | upernavik
# Processing Record 27 of Set 1 | avarua
# Processing Record 28 of Set 1 | cape town
# Processing Record 29 of Set 1 | ushuaia
# Processing Record 30 of Set 1 | dingle
# Processing Record 31 of Set 1 | puerto ayora
# Processing Record 32 of Set 1 | provideniya
# Processing Record 33 of Set 1 | albany
# Processing Record 34 of Set 1 | alenquer
# Processing Record 35 of Set 1 | asau
# Processing Record 36 of Set 1 | qaanaaq
# Processing Record 37 of Set 1 | moron
# Processing Record 38 of Set 1 | klaksvik
# Processing Record 39 of Set 1 | ponta do sol
# Processing Record 40 of Set 1 | sao filipe
# Processing Record 41 of Set 1 | saint-philippe
# Processing Record 42 of Set 1 | ilulissat
# Processing Record 43 of Set 1 | tuktoyaktuk
# Processing Record 44 of Set 1 | east london
# Processing Record 45 of Set 1 | zeya
# Processing Record 46 of Set 1 | alta floresta
# Processing Record 47 of Set 1 | verkhnevilyuysk
# Processing Record 48 of Set 1 | freeport
# Processing Record 49 of Set 1 | kuhdasht
# Processing Record 50 of Set 1 | bethel
# Processing Record 1 of Set 2 | hilo
# Processing Record 2 of Set 2 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 3 of Set 2 | comodoro rivadavia
# Processing Record 4 of Set 2 | vila franca do campo
# Processing Record 5 of Set 2 | zarubino
# Processing Record 6 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 2 | saint george
# Processing Record 8 of Set 2 | pskov
# Processing Record 9 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 2 | touros
# Processing Record 12 of Set 2 | yar-sale
# Processing Record 13 of Set 2 | calvinia
# Processing Record 14 of Set 2 | kozhva
# Processing Record 15 of Set 2 | guekedou
# City not found. Skipping...
# Processing Record 16 of Set 2 | pochutla
# Processing Record 17 of Set 2 | salalah
# Processing Record 18 of Set 2 | lasa
# Processing Record 19 of Set 2 | havre-saint-pierre
# Processing Record 20 of Set 2 | aksarka
# Processing Record 21 of Set 2 | tabou
# Processing Record 22 of Set 2 | charters towers
# Processing Record 23 of Set 2 | amapa
# Processing Record 24 of Set 2 | vardo
# Processing Record 25 of Set 2 | waslala
# Processing Record 26 of Set 2 | longyearbyen
# Processing Record 27 of Set 2 | sidney
# Processing Record 28 of Set 2 | tramagal
# Processing Record 29 of Set 2 | ostrovnoy
# Processing Record 30 of Set 2 | necochea
# Processing Record 31 of Set 2 | barrow
# Processing Record 32 of Set 2 | regina
# Processing Record 33 of Set 2 | lagoa
# Processing Record 34 of Set 2 | emerald
# Processing Record 35 of Set 2 | yulara
# Processing Record 36 of Set 2 | nikki
# Processing Record 37 of Set 2 | victoria
# Processing Record 38 of Set 2 | portland
# Processing Record 39 of Set 2 | dikson
# Processing Record 40 of Set 2 | bengkulu
# Processing Record 41 of Set 2 | vaitape
# Processing Record 42 of Set 2 | jiddah
# City not found. Skipping...
# Processing Record 43 of Set 2 | mega
# Processing Record 44 of Set 2 | puerto madryn
# Processing Record 45 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 2 | roald
# Processing Record 47 of Set 2 | altamira
# Processing Record 48 of Set 2 | adwa
# Processing Record 49 of Set 2 | viedma
# Processing Record 50 of Set 2 | plouzane
# Processing Record 1 of Set 3 | ust-koksa
# Processing Record 2 of Set 3 | samana
# Processing Record 3 of Set 3 | warrington
# Processing Record 4 of Set 3 | new norfolk
# Processing Record 5 of Set 3 | honningsvag
# Processing Record 6 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 7 of Set 3 | ylivieska
# Processing Record 8 of Set 3 | kavieng
# Processing Record 9 of Set 3 | ajaccio
# Processing Record 10 of Set 3 | chokurdakh
# Processing Record 11 of Set 3 | cururupu
# Processing Record 12 of Set 3 | wattegama
# Processing Record 13 of Set 3 | vaini
# Processing Record 14 of Set 3 | arraial do cabo
# Processing Record 15 of Set 3 | tazovskiy
# Processing Record 16 of Set 3 | mehamn
# Processing Record 17 of Set 3 | namibe
# Processing Record 18 of Set 3 | cairns
# Processing Record 19 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 20 of Set 3 | nuevo progreso
# Processing Record 21 of Set 3 | kasongo
# Processing Record 22 of Set 3 | maloy
# Processing Record 23 of Set 3 | kodiak
# Processing Record 24 of Set 3 | dzhebariki-khaya
# Processing Record 25 of Set 3 | datia
# Processing Record 26 of Set 3 | kirakira
# Processing Record 27 of Set 3 | saskylakh
# Processing Record 28 of Set 3 | samalkha
# Processing Record 29 of Set 3 | carnarvon
# Processing Record 30 of Set 3 | yellowknife
# Processing Record 31 of Set 3 | florianopolis
# Processing Record 32 of Set 3 | praia da vitoria
# Processing Record 33 of Set 3 | thinadhoo
# Processing Record 34 of Set 3 | morro bay
# Processing Record 35 of Set 3 | chihuahua
# Processing Record 36 of Set 3 | puerto montt
# Processing Record 37 of Set 3 | coihaique
# Processing Record 38 of Set 3 | sitka
# Processing Record 39 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 40 of Set 3 | airai
# Processing Record 41 of Set 3 | karratha
# Processing Record 42 of Set 3 | khatanga
# Processing Record 43 of Set 3 | caravelas
# Processing Record 44 of Set 3 | changli
# Processing Record 45 of Set 3 | ginda
# Processing Record 46 of Set 3 | atar
# Processing Record 47 of Set 3 | nikolskoye
# Processing Record 48 of Set 3 | chuy
# Processing Record 49 of Set 3 | bredasdorp
# Processing Record 50 of Set 3 | cockburn town
# Processing Record 1 of Set 4 | prachuap khiri khan
# Processing Record 2 of Set 4 | savalou
# Processing Record 3 of Set 4 | teruel
# Processing Record 4 of Set 4 | atuona
# Processing Record 5 of Set 4 | talnakh
# Processing Record 6 of Set 4 | aklavik
# Processing Record 7 of Set 4 | plettenberg bay
# Processing Record 8 of Set 4 | hit
# Processing Record 9 of Set 4 | jamestown
# Processing Record 10 of Set 4 | ribeira grande
# Processing Record 11 of Set 4 | mandalgovi
# Processing Record 12 of Set 4 | chumikan
# Processing Record 13 of Set 4 | tahta
# Processing Record 14 of Set 4 | cabo san lucas
# Processing Record 15 of Set 4 | constitucion
# Processing Record 16 of Set 4 | ancud
# Processing Record 17 of Set 4 | nador
# Processing Record 18 of Set 4 | butaritari
# Processing Record 19 of Set 4 | rawson
# Processing Record 20 of Set 4 | glyadyanskoye
# Processing Record 21 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 4 | lebu
# Processing Record 23 of Set 4 | mogadishu
# Processing Record 24 of Set 4 | port blair
# Processing Record 25 of Set 4 | itarema
# Processing Record 26 of Set 4 | baculin
# Processing Record 27 of Set 4 | amberley
# Processing Record 28 of Set 4 | guapore
# Processing Record 29 of Set 4 | platteville
# Processing Record 30 of Set 4 | evensk
# Processing Record 31 of Set 4 | codrington
# Processing Record 32 of Set 4 | zheleznodorozhnyy
# Processing Record 33 of Set 4 | krasnoye
# Processing Record 34 of Set 4 | quilali
# Processing Record 35 of Set 4 | tukrah
# Processing Record 36 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 37 of Set 4 | saint-joseph
# Processing Record 38 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 39 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 40 of Set 4 | felanitx
# Processing Record 41 of Set 4 | gulf gate estates
# Processing Record 42 of Set 4 | buala
# Processing Record 43 of Set 4 | kudahuvadhoo
# Processing Record 44 of Set 4 | kirkwall
# Processing Record 45 of Set 4 | hobart
# Processing Record 46 of Set 4 | inuvik
# Processing Record 47 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 4 | seoul
# Processing Record 49 of Set 4 | terrace
# Processing Record 50 of Set 4 | mar del plata
# Processing Record 1 of Set 5 | sebinkarahisar
# Processing Record 2 of Set 5 | ahipara
# Processing Record 3 of Set 5 | saint-ambroise
# Processing Record 4 of Set 5 | batagay-alyta
# Processing Record 5 of Set 5 | machali
# Processing Record 6 of Set 5 | vao
# Processing Record 7 of Set 5 | warri
# Processing Record 8 of Set 5 | mildura
# Processing Record 9 of Set 5 | lokosovo
# Processing Record 10 of Set 5 | mount gambier
# Processing Record 11 of Set 5 | qaqortoq
# Processing Record 12 of Set 5 | lata
# Processing Record 13 of Set 5 | imbituba
# Processing Record 14 of Set 5 | pauini
# Processing Record 15 of Set 5 | aktau
# Processing Record 16 of Set 5 | mayuge
# Processing Record 17 of Set 5 | richards bay
# Processing Record 18 of Set 5 | guntur
# Processing Record 19 of Set 5 | bilma
# Processing Record 20 of Set 5 | melilla
# Processing Record 21 of Set 5 | cherskiy
# Processing Record 22 of Set 5 | cooma
# Processing Record 23 of Set 5 | vestmannaeyjar
# Processing Record 24 of Set 5 | longlac
# City not found. Skipping...
# Processing Record 25 of Set 5 | carpentras
# Processing Record 26 of Set 5 | tiksi
# Processing Record 27 of Set 5 | clyde river
# Processing Record 28 of Set 5 | kruisfontein
# Processing Record 29 of Set 5 | fond du lac
# Processing Record 30 of Set 5 | nanortalik
# Processing Record 31 of Set 5 | bambanglipuro
# Processing Record 32 of Set 5 | maiduguri
# Processing Record 33 of Set 5 | isangel
# Processing Record 34 of Set 5 | sergeyevka
# Processing Record 35 of Set 5 | anadyr
# Processing Record 36 of Set 5 | kahului
# Processing Record 37 of Set 5 | mitu
# Processing Record 38 of Set 5 | kaeo
# Processing Record 39 of Set 5 | puerto gaitan
# Processing Record 40 of Set 5 | hambantota
# Processing Record 41 of Set 5 | jiwani
# Processing Record 42 of Set 5 | mareeba
# Processing Record 43 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 5 | malakal
# Processing Record 45 of Set 5 | beloha
# Processing Record 46 of Set 5 | hasaki
# Processing Record 47 of Set 5 | sur
# Processing Record 48 of Set 5 | solnechnyy
# Processing Record 49 of Set 5 | tasiilaq
# Processing Record 50 of Set 5 | guerrero negro
# Processing Record 1 of Set 6 | dergaon
# Processing Record 2 of Set 6 | thompson
# Processing Record 3 of Set 6 | petatlan
# Processing Record 4 of Set 6 | quatre cocos
# Processing Record 5 of Set 6 | biak
# Processing Record 6 of Set 6 | gamba
# Processing Record 7 of Set 6 | cheuskiny
# City not found. Skipping...
# Processing Record 8 of Set 6 | port hedland
# Processing Record 9 of Set 6 | bathsheba
# Processing Record 10 of Set 6 | esmeralda
# Processing Record 11 of Set 6 | abu kamal
# Processing Record 12 of Set 6 | mahebourg
# Processing Record 13 of Set 6 | grindavik
# Processing Record 14 of Set 6 | tuatapere
# Processing Record 15 of Set 6 | veraval
# Processing Record 16 of Set 6 | kaitangata
# Processing Record 17 of Set 6 | vila
# Processing Record 18 of Set 6 | souillac
# Processing Record 19 of Set 6 | narsaq
# Processing Record 20 of Set 6 | alice springs
# Processing Record 21 of Set 6 | jiuquan
# Processing Record 22 of Set 6 | kerman
# Processing Record 23 of Set 6 | samarai
# Processing Record 24 of Set 6 | westport
# Processing Record 25 of Set 6 | labutta
# City not found. Skipping...
# Processing Record 26 of Set 6 | orsha
# Processing Record 27 of Set 6 | kloulklubed
# Processing Record 28 of Set 6 | rio gallegos
# Processing Record 29 of Set 6 | port-gentil
# Processing Record 30 of Set 6 | bokajan
# Processing Record 31 of Set 6 | esperance
# Processing Record 32 of Set 6 | umarkot
# Processing Record 33 of Set 6 | los llanos de aridane
# Processing Record 34 of Set 6 | dawlatabad
# Processing Record 35 of Set 6 | mirador
# Processing Record 36 of Set 6 | chipata
# Processing Record 37 of Set 6 | norman wells
# Processing Record 38 of Set 6 | puri
# Processing Record 39 of Set 6 | tucurui
# Processing Record 40 of Set 6 | pangoa
# Processing Record 41 of Set 6 | brewster
# Processing Record 42 of Set 6 | santa lucia
# Processing Record 43 of Set 6 | xining
# Processing Record 44 of Set 6 | padang
# Processing Record 45 of Set 6 | yangshe
# Processing Record 46 of Set 6 | outjo
# Processing Record 47 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 48 of Set 6 | kamenka
# Processing Record 49 of Set 6 | pervomayskiy
# Processing Record 50 of Set 6 | balgazyn
# Processing Record 1 of Set 7 | west lafayette
# Processing Record 2 of Set 7 | young
# Processing Record 3 of Set 7 | pemangkat
# Processing Record 4 of Set 7 | grand gaube
# Processing Record 5 of Set 7 | monroe
# Processing Record 6 of Set 7 | quesnel
# Processing Record 7 of Set 7 | jalu
# Processing Record 8 of Set 7 | fairbanks
# Processing Record 9 of Set 7 | geraldton
# Processing Record 10 of Set 7 | jizan
# Processing Record 11 of Set 7 | koumac
# Processing Record 12 of Set 7 | itaituba
# Processing Record 13 of Set 7 | poum
# Processing Record 14 of Set 7 | qostanay
# Processing Record 15 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 16 of Set 7 | mount isa
# Processing Record 17 of Set 7 | soskovo
# Processing Record 18 of Set 7 | opuwo
# Processing Record 19 of Set 7 | leningradskiy
# Processing Record 20 of Set 7 | khao yoi
# Processing Record 21 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 22 of Set 7 | utete
# Processing Record 23 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 24 of Set 7 | mudyuga
# City not found. Skipping...
# Processing Record 25 of Set 7 | watsa
# Processing Record 26 of Set 7 | maraa
# Processing Record 27 of Set 7 | qandahar
# City not found. Skipping...
# Processing Record 28 of Set 7 | colares
# Processing Record 29 of Set 7 | odienne
# Processing Record 30 of Set 7 | fortuna
# Processing Record 31 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 7 | seymchan
# Processing Record 33 of Set 7 | isla vista
# Processing Record 34 of Set 7 | san rafael
# Processing Record 35 of Set 7 | asfi
# Processing Record 36 of Set 7 | saldanha
# Processing Record 37 of Set 7 | maldonado
# Processing Record 38 of Set 7 | nakhodka
# Processing Record 39 of Set 7 | ino
# Processing Record 40 of Set 7 | georgetown
# Processing Record 41 of Set 7 | hami
# Processing Record 42 of Set 7 | palmer
# Processing Record 43 of Set 7 | darhan
# Processing Record 44 of Set 7 | buraydah
# Processing Record 45 of Set 7 | matamoros
# Processing Record 46 of Set 7 | sao felix do xingu
# Processing Record 47 of Set 7 | erzin
# Processing Record 48 of Set 7 | phayao
# Processing Record 49 of Set 7 | severo-kurilsk
# Processing Record 50 of Set 7 | lakes entrance
# Processing Record 1 of Set 8 | kitsuki
# Processing Record 2 of Set 8 | sarakhs
# Processing Record 3 of Set 8 | shimoda
# Processing Record 4 of Set 8 | mae hong son
# Processing Record 5 of Set 8 | brigantine
# Processing Record 6 of Set 8 | sampit
# Processing Record 7 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 8 | sabang
# Processing Record 9 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 10 of Set 8 | sretensk
# Processing Record 11 of Set 8 | high level
# Processing Record 12 of Set 8 | buon me thuot
# City not found. Skipping...
# Processing Record 13 of Set 8 | campbell river
# Processing Record 14 of Set 8 | hay river
# Processing Record 15 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 16 of Set 8 | ales
# Processing Record 17 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 8 | neiafu
# Processing Record 19 of Set 8 | oksfjord
# Processing Record 20 of Set 8 | axim
# Processing Record 21 of Set 8 | belmonte
# Processing Record 22 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 23 of Set 8 | kiunga
# Processing Record 24 of Set 8 | vangaindrano
# Processing Record 25 of Set 8 | ulaangom
# Processing Record 26 of Set 8 | tingrela
# City not found. Skipping...
# Processing Record 27 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 28 of Set 8 | pisco
# Processing Record 29 of Set 8 | bud
# Processing Record 30 of Set 8 | farafangana
# Processing Record 31 of Set 8 | linjiang
# Processing Record 32 of Set 8 | castro
# Processing Record 33 of Set 8 | toktogul
# Processing Record 34 of Set 8 | pevek
# Processing Record 35 of Set 8 | tyukhtet
# Processing Record 36 of Set 8 | ustye
# Processing Record 37 of Set 8 | sao miguel do araguaia
# Processing Record 38 of Set 8 | wanxian
# Processing Record 39 of Set 8 | nome
# Processing Record 40 of Set 8 | florenville
# Processing Record 41 of Set 8 | karmala
# Processing Record 42 of Set 8 | chapais
# Processing Record 43 of Set 8 | college
# Processing Record 44 of Set 8 | ayotzintepec
# Processing Record 45 of Set 8 | kaka
# Processing Record 46 of Set 8 | sofiysk
# City not found. Skipping...
# Processing Record 47 of Set 8 | sar-e pul
# Processing Record 48 of Set 8 | torbay
# Processing Record 49 of Set 8 | kargasok
# Processing Record 50 of Set 8 | nyrob
# Processing Record 1 of Set 9 | pokrovsk
# Processing Record 2 of Set 9 | ust-tsilma
# Processing Record 3 of Set 9 | sabha
# Processing Record 4 of Set 9 | purpe
# Processing Record 5 of Set 9 | yinchuan
# Processing Record 6 of Set 9 | nizwa
# Processing Record 7 of Set 9 | murdochville
# Processing Record 8 of Set 9 | hunterville
# Processing Record 9 of Set 9 | xai-xai
# Processing Record 10 of Set 9 | bubaque
# Processing Record 11 of Set 9 | dandong
# Processing Record 12 of Set 9 | taoudenni
# Processing Record 13 of Set 9 | ihosy
# Processing Record 14 of Set 9 | kitui
# Processing Record 15 of Set 9 | arinos
# Processing Record 16 of Set 9 | dzhusaly
# City not found. Skipping...
# Processing Record 17 of Set 9 | jiquinlaca
# Processing Record 18 of Set 9 | rakhya
# City not found. Skipping...
# Processing Record 19 of Set 9 | valparaiso
# Processing Record 20 of Set 9 | turkmenabat
# Processing Record 21 of Set 9 | bayburt
# Processing Record 22 of Set 9 | salima
# Processing Record 23 of Set 9 | jibuti
# Processing Record 24 of Set 9 | tomari
# Processing Record 25 of Set 9 | mato verde
# Processing Record 26 of Set 9 | pizarro
# Processing Record 27 of Set 9 | aklera
# Processing Record 28 of Set 9 | henties bay
# Processing Record 29 of Set 9 | komsomolskiy
# Processing Record 30 of Set 9 | redmond
# Processing Record 31 of Set 9 | janakkala
# Processing Record 32 of Set 9 | umm kaddadah
# Processing Record 33 of Set 9 | tateyama
# Processing Record 34 of Set 9 | arlit
# Processing Record 35 of Set 9 | stornoway
# Processing Record 36 of Set 9 | ouadda
# Processing Record 37 of Set 9 | houlton
# Processing Record 38 of Set 9 | zhangye
# Processing Record 39 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 40 of Set 9 | panuco
# Processing Record 41 of Set 9 | tucumcari
# Processing Record 42 of Set 9 | luba
# Processing Record 43 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 44 of Set 9 | havoysund
# Processing Record 45 of Set 9 | kununurra
# Processing Record 46 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 47 of Set 9 | avera
# Processing Record 48 of Set 9 | faanui
# Processing Record 49 of Set 9 | tuban
# Processing Record 50 of Set 9 | ipixuna
# Processing Record 1 of Set 10 | saint-pierre
# Processing Record 2 of Set 10 | lompoc
# Processing Record 3 of Set 10 | afrikanda
# Processing Record 4 of Set 10 | tiznit
# Processing Record 5 of Set 10 | vershino-darasunskiy
# Processing Record 6 of Set 10 | barra do garcas
# Processing Record 7 of Set 10 | tiarei
# Processing Record 8 of Set 10 | fuerte olimpo
# Processing Record 9 of Set 10 | kisangani
# Processing Record 10 of Set 10 | awjilah
# Processing Record 11 of Set 10 | the valley
# Processing Record 12 of Set 10 | wanaka
# Processing Record 13 of Set 10 | tighnabruaich
# Processing Record 14 of Set 10 | pampa
# Processing Record 15 of Set 10 | juneau
# Processing Record 16 of Set 10 | gat
# Processing Record 17 of Set 10 | porbandar
# Processing Record 18 of Set 10 | dhidhdhoo
# Processing Record 19 of Set 10 | kayerkan
# Processing Record 20 of Set 10 | sakakah
# Processing Record 21 of Set 10 | chongwe
# Processing Record 22 of Set 10 | bocas del toro
# Processing Record 23 of Set 10 | tungor
# Processing Record 24 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 25 of Set 10 | otradnoye
# Processing Record 26 of Set 10 | san cristobal
# Processing Record 27 of Set 10 | ust-nera
# Processing Record 28 of Set 10 | robertsport
# Processing Record 29 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 30 of Set 10 | piracanjuba
# Processing Record 31 of Set 10 | tura
# Processing Record 32 of Set 10 | swellendam
# Processing Record 33 of Set 10 | iqaluit
# Processing Record 34 of Set 10 | pangkalanbuun
# Processing Record 35 of Set 10 | nemuro
# Processing Record 36 of Set 10 | paamiut
# Processing Record 37 of Set 10 | salto
# Processing Record 38 of Set 10 | vanavara
# Processing Record 39 of Set 10 | semirom
# Processing Record 40 of Set 10 | ballina
# Processing Record 41 of Set 10 | saint-augustin
# Processing Record 42 of Set 10 | lavrentiya
# Processing Record 43 of Set 10 | portobelo
# Processing Record 44 of Set 10 | haines junction
# Processing Record 45 of Set 10 | keflavik
# Processing Record 46 of Set 10 | vrangel
# Processing Record 47 of Set 10 | novoilinsk
# Processing Record 48 of Set 10 | sao jose da coroa grande
# Processing Record 49 of Set 10 | big spring
# Processing Record 50 of Set 10 | taltal
# Processing Record 1 of Set 11 | cochrane
# Processing Record 2 of Set 11 | tapaua
# City not found. Skipping...
# Processing Record 3 of Set 11 | jimenez
# Processing Record 4 of Set 11 | port augusta
# Processing Record 5 of Set 11 | onega
# Processing Record 6 of Set 11 | lubao
# Processing Record 7 of Set 11 | akdepe
# Processing Record 8 of Set 11 | bolobo
# Processing Record 9 of Set 11 | olafsvik
# Processing Record 10 of Set 11 | beeville
# Processing Record 11 of Set 11 | sambava
# Processing Record 12 of Set 11 | morondava
# Processing Record 13 of Set 11 | takaka
# Processing Record 14 of Set 11 | maracaibo
# Processing Record 15 of Set 11 | mabaruma
# Processing Record 16 of Set 11 | northview
# Processing Record 17 of Set 11 | toccoa
# Processing Record 18 of Set 11 | oriximina
# Processing Record 19 of Set 11 | ploemeur
# Processing Record 20 of Set 11 | ulladulla
# Processing Record 21 of Set 11 | palmerston
# Processing Record 22 of Set 11 | natchez
# Processing Record 23 of Set 11 | bandarbeyla
# Processing Record 24 of Set 11 | maceio
# Processing Record 25 of Set 11 | tautira
# Processing Record 26 of Set 11 | sibu
# Processing Record 27 of Set 11 | hofn
# Processing Record 28 of Set 11 | hachinohe
# Processing Record 29 of Set 11 | shingu
# Processing Record 30 of Set 11 | gogapur
# Processing Record 31 of Set 11 | petropavlovskoye
# Processing Record 32 of Set 11 | alofi
# Processing Record 33 of Set 11 | sokolo
# Processing Record 34 of Set 11 | maniitsoq
# Processing Record 35 of Set 11 | leopold
# Processing Record 36 of Set 11 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 37 of Set 11 | bairiki
# Processing Record 38 of Set 11 | bambous virieux
# Processing Record 39 of Set 11 | meulaboh
# Processing Record 40 of Set 11 | manhumirim
# Processing Record 41 of Set 11 | te anau
# Processing Record 42 of Set 11 | dengzhou
# Processing Record 43 of Set 11 | idlib
# Processing Record 44 of Set 11 | shestakovo
# Processing Record 45 of Set 11 | oktyabrskoye
# Processing Record 46 of Set 11 | hua hin
# Processing Record 47 of Set 11 | ajdabiya
# Processing Record 48 of Set 11 | labuhan
# Processing Record 49 of Set 11 | gayny
# Processing Record 50 of Set 11 | broome
# Processing Record 1 of Set 12 | knysna
# Processing Record 2 of Set 12 | hobyo
# Processing Record 3 of Set 12 | yingzhong
# City not found. Skipping...
# Processing Record 4 of Set 12 | ponta delgada
# Processing Record 5 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 6 of Set 12 | rumuruti
# Processing Record 7 of Set 12 | motygino
# Processing Record 8 of Set 12 | muzhi
# Processing Record 9 of Set 12 | kysyl-syr
# Processing Record 10 of Set 12 | doha
# Processing Record 11 of Set 12 | narva-joesuu
# Processing Record 12 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 12 | moindou
# Processing Record 14 of Set 12 | yabelo
# Processing Record 15 of Set 12 | dakar
# Processing Record 16 of Set 12 | manaure
# Processing Record 17 of Set 12 | vila velha
# Processing Record 18 of Set 12 | madras
# Processing Record 19 of Set 12 | sukumo
# Processing Record 20 of Set 12 | placido de castro
# Processing Record 21 of Set 12 | dali
# Processing Record 22 of Set 12 | gizo
# Processing Record 23 of Set 12 | fomboni
# Processing Record 24 of Set 12 | krasnoselkup
# Processing Record 25 of Set 12 | dongobesh
# Processing Record 26 of Set 12 | panacan
# Processing Record 27 of Set 12 | shumskiy
# Processing Record 28 of Set 12 | voh
# Processing Record 29 of Set 12 | coahuayana
# Processing Record 30 of Set 12 | cabedelo
# Processing Record 31 of Set 12 | san jeronimo
# Processing Record 32 of Set 12 | esmeraldas
# Processing Record 33 of Set 12 | nago
# Processing Record 34 of Set 12 | balabac
# Processing Record 35 of Set 12 | hualmay
# Processing Record 36 of Set 12 | athabasca
# Processing Record 37 of Set 12 | santa vitoria do palmar
# Processing Record 38 of Set 12 | papar
# Processing Record 39 of Set 12 | pafos
# Processing Record 40 of Set 12 | hun
# Processing Record 41 of Set 12 | bendigo
# Processing Record 42 of Set 12 | natal
# Processing Record 43 of Set 12 | kimbe
# Processing Record 44 of Set 12 | point pedro
# Processing Record 45 of Set 12 | lubumbashi
# Processing Record 46 of Set 12 | nouadhibou
# Processing Record 47 of Set 12 | pacific grove
# Processing Record 48 of Set 12 | yuxia
# Processing Record 49 of Set 12 | okhotsk
# Processing Record 50 of Set 12 | orsk
# Processing Record 1 of Set 13 | wahran
# City not found. Skipping...
# Processing Record 2 of Set 13 | farmington
# Processing Record 3 of Set 13 | charlottetown
# Processing Record 4 of Set 13 | campoverde
# Processing Record 5 of Set 13 | ubinskoye
# Processing Record 6 of Set 13 | oranjestad
# Processing Record 7 of Set 13 | chauk
# Processing Record 8 of Set 13 | juifang
# City not found. Skipping...
# Processing Record 9 of Set 13 | shakawe
# Processing Record 10 of Set 13 | pangnirtung
# Processing Record 11 of Set 13 | tawkar
# City not found. Skipping...
# Processing Record 12 of Set 13 | blue island
# Processing Record 13 of Set 13 | bykov
# Processing Record 14 of Set 13 | bermeo
# Processing Record 15 of Set 13 | muisne
# Processing Record 16 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 17 of Set 13 | manono
# Processing Record 18 of Set 13 | standerton
# Processing Record 19 of Set 13 | ituni
# City not found. Skipping...
# Processing Record 20 of Set 13 | harrison
# Processing Record 21 of Set 13 | acapulco
# Processing Record 22 of Set 13 | lysyanka
# Processing Record 23 of Set 13 | sakaiminato
# Processing Record 24 of Set 13 | alizai
# Processing Record 25 of Set 13 | lerwick
# Processing Record 26 of Set 13 | kita
# Processing Record 27 of Set 13 | ladyzhyn
# Processing Record 28 of Set 13 | shakhtinsk
# Processing Record 29 of Set 13 | khandbari
# Processing Record 30 of Set 13 | talaya
# Processing Record 31 of Set 13 | contramaestre
# Processing Record 32 of Set 13 | woodward
# Processing Record 33 of Set 13 | andenes
# Processing Record 34 of Set 13 | kuandian
# Processing Record 35 of Set 13 | egvekinot
# Processing Record 36 of Set 13 | meadow lake
# Processing Record 37 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 38 of Set 13 | tsalka
# Processing Record 39 of Set 13 | mankono
# Processing Record 40 of Set 13 | shiloh
# Processing Record 41 of Set 13 | flinders
# Processing Record 42 of Set 13 | strai
# Processing Record 43 of Set 13 | lazaro cardenas
# Processing Record 44 of Set 13 | cartagena del chaira
# Processing Record 45 of Set 13 | inzer
# Processing Record 46 of Set 13 | toora-khem
# Processing Record 47 of Set 13 | ternate
# Processing Record 48 of Set 13 | creel
# Processing Record 49 of Set 13 | tselinnoye
# Processing Record 50 of Set 13 | copiapo
# Processing Record 1 of Set 14 | maragogi
# Processing Record 2 of Set 14 | coquimbo
# Processing Record 3 of Set 14 | cayenne
# Processing Record 4 of Set 14 | huajuapan
# City not found. Skipping...
# Processing Record 5 of Set 14 | kiruna
# Processing Record 6 of Set 14 | miracatu
# Processing Record 7 of Set 14 | la ronge
# Processing Record 8 of Set 14 | mbaiki
# Processing Record 9 of Set 14 | bitung
# Processing Record 10 of Set 14 | springbok
# Processing Record 11 of Set 14 | kupang
# Processing Record 12 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 13 of Set 14 | ust-kan
# Processing Record 14 of Set 14 | surgut
# Processing Record 15 of Set 14 | khor
# Processing Record 16 of Set 14 | diffa
# Processing Record 17 of Set 14 | belaya gora
# Processing Record 18 of Set 14 | penzance
# Processing Record 19 of Set 14 | lorengau
# Processing Record 20 of Set 14 | huilong
# Processing Record 21 of Set 14 | mora
# Processing Record 22 of Set 14 | xinqing
# Processing Record 23 of Set 14 | barcelona
# Processing Record 24 of Set 14 | spornoye
# Processing Record 25 of Set 14 | dibaya
# City not found. Skipping...
# Processing Record 26 of Set 14 | nantucket
# Processing Record 27 of Set 14 | shcholkine
# City not found. Skipping...
# Processing Record 28 of Set 14 | dawei
# Processing Record 29 of Set 14 | weymouth
# Processing Record 30 of Set 14 | tommot
# Processing Record 31 of Set 14 | american canyon
# Processing Record 32 of Set 14 | yerbogachen
# Processing Record 33 of Set 14 | sayville
# Processing Record 34 of Set 14 | dvinskoy
# Processing Record 35 of Set 14 | bundaberg
# Processing Record 36 of Set 14 | alugan
# Processing Record 37 of Set 14 | oyonnax
# Processing Record 38 of Set 14 | paita
# Processing Record 39 of Set 14 | montepuez
# Processing Record 40 of Set 14 | bilibino
# Processing Record 41 of Set 14 | grafton
# Processing Record 42 of Set 14 | kedrovyy
# Processing Record 43 of Set 14 | moranbah
# Processing Record 44 of Set 14 | taga
# Processing Record 45 of Set 14 | kijang
# Processing Record 46 of Set 14 | laguna
# Processing Record 47 of Set 14 | daru
# Processing Record 48 of Set 14 | gillette
# Processing Record 49 of Set 14 | malanje
# Processing Record 50 of Set 14 | mantua
# Processing Record 1 of Set 15 | fort myers beach
# Processing Record 2 of Set 15 | najran
# Processing Record 3 of Set 15 | preobrazheniye
# Processing Record 4 of Set 15 | malindi
# Processing Record 5 of Set 15 | katiola
# Processing Record 6 of Set 15 | killybegs
# Processing Record 7 of Set 15 | half moon bay
# Processing Record 8 of Set 15 | shenxian
# Processing Record 9 of Set 15 | ayorou
# Processing Record 10 of Set 15 | tambacounda
# Processing Record 11 of Set 15 | ewa beach
# Processing Record 12 of Set 15 | mucurapo
# Processing Record 13 of Set 15 | morant bay
# Processing Record 14 of Set 15 | paysandu
# Processing Record 15 of Set 15 | kasongo-lunda
# Processing Record 16 of Set 15 | broken hill
# Processing Record 17 of Set 15 | kamloops
# Processing Record 18 of Set 15 | bahia honda
# Processing Record 19 of Set 15 | celestun
# Processing Record 20 of Set 15 | musoma
# Processing Record 21 of Set 15 | rudarpur
# Processing Record 22 of Set 15 | puerto madero
# Processing Record 23 of Set 15 | husavik
# Processing Record 24 of Set 15 | whitianga
# Processing Record 25 of Set 15 | chopinzinho
# Processing Record 26 of Set 15 | ranong
# Processing Record 27 of Set 15 | markova
# Processing Record 28 of Set 15 | arman
# Processing Record 29 of Set 15 | marienburg
# Processing Record 30 of Set 15 | berlevag
# Processing Record 31 of Set 15 | ugoofaaru
# Processing Record 32 of Set 15 | carinhanha
# Processing Record 33 of Set 15 | port macquarie
# Processing Record 34 of Set 15 | port hardy
# Processing Record 35 of Set 15 | gisborne
# Processing Record 36 of Set 15 | ati
# Processing Record 37 of Set 15 | ciudad bolivar
# Processing Record 38 of Set 15 | weligama
# Processing Record 39 of Set 15 | villa carlos paz
# Processing Record 40 of Set 15 | katsuura
# Processing Record 41 of Set 15 | kuznechnoye
# Processing Record 42 of Set 15 | oranjemund
# Processing Record 43 of Set 15 | xiangdong
# City not found. Skipping...
# Processing Record 44 of Set 15 | san vicente
# Processing Record 45 of Set 15 | demba
# Processing Record 46 of Set 15 | balagansk
# Processing Record 47 of Set 15 | praia
# Processing Record 48 of Set 15 | sozopol
# Processing Record 49 of Set 15 | mackay
# Processing Record 50 of Set 15 | sobolevo
# Processing Record 1 of Set 16 | aldama
# Processing Record 2 of Set 16 | bibiani
# Processing Record 3 of Set 16 | slave lake
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 693

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Hithadhoo  -0.6000   73.0833     83.88        69          95
# 1            Auki  -8.7676  160.7034     79.41        83         100
# 2    Punta Arenas -53.1500  -70.9167     41.11        82           0
# 3           Dekar -21.5333   21.9333     55.08        54           0
# 4        Hermanus -34.4187   19.2345     57.79        50          67
# 5  Port Elizabeth -33.9180   25.5701     59.09        34          37
# 6         Rikitea -23.1203 -134.9692     74.53        68          61
# 7          Ca Mau   9.1769  105.1500     80.55        81          99
# 8          Manado   1.4870  124.8455     81.37        69          20
# 9    San Patricio  28.0170  -97.5169     82.87        75          68
#
#    Wind Speed Country Weather Description
# 0       11.77      MV     overcast clouds
# 1        6.31      SB     overcast clouds
# 2       14.09      CL           clear sky
# 3        8.77      BW           clear sky
# 4        7.99      ZA       broken clouds
# 5        8.21      ZA    scattered clouds
# 6        2.89      PF       broken clouds
# 7       12.75      VN     overcast clouds
# 8        4.16      ID          few clouds
# 9       12.08      US       broken clouds

# %%
city_data_df = city_data_df[['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Weather Description']]
city_data_df
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Hithadhoo      MV  -0.6000   73.0833     83.88        69          95
# 1            Auki      SB  -8.7676  160.7034     79.41        83         100
# 2    Punta Arenas      CL -53.1500  -70.9167     41.11        82           0
# 3           Dekar      BW -21.5333   21.9333     55.08        54           0
# 4        Hermanus      ZA -34.4187   19.2345     57.79        50          67
# ..            ...     ...      ...       ...       ...       ...         ...
# 688        Mackay      AU -21.1500  149.2000     76.68        78          16
# 689      Sobolevo      RU  54.4299   31.8996     45.64        97          32
# 690        Aldama      MX  22.9167  -98.0667     87.82        65           6
# 691       Bibiani      GH   6.4635   -2.3194     72.72        98          97
# 692    Slave Lake      CA  55.2834 -114.7690     66.83        44          84
#
#      Wind Speed Weather Description
# 0         11.77     overcast clouds
# 1          6.31     overcast clouds
# 2         14.09           clear sky
# 3          8.77           clear sky
# 4          7.99       broken clouds
# ..          ...                 ...
# 688       18.66          few clouds
# 689        6.82    scattered clouds
# 690       13.40           clear sky
# 691        1.79     overcast clouds
# 692        2.17       moderate rain
#
# [693 rows x 9 columns]

# %%
city_data_df.rename(columns={"Weather Description": "Current Description"}, inplace = True)
city_data_df
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Hithadhoo      MV  -0.6000   73.0833     83.88        69          95
# 1            Auki      SB  -8.7676  160.7034     79.41        83         100
# 2    Punta Arenas      CL -53.1500  -70.9167     41.11        82           0
# 3           Dekar      BW -21.5333   21.9333     55.08        54           0
# 4        Hermanus      ZA -34.4187   19.2345     57.79        50          67
# ..            ...     ...      ...       ...       ...       ...         ...
# 688        Mackay      AU -21.1500  149.2000     76.68        78          16
# 689      Sobolevo      RU  54.4299   31.8996     45.64        97          32
# 690        Aldama      MX  22.9167  -98.0667     87.82        65           6
# 691       Bibiani      GH   6.4635   -2.3194     72.72        98          97
# 692    Slave Lake      CA  55.2834 -114.7690     66.83        44          84
#
#      Wind Speed Current Description
# 0         11.77     overcast clouds
# 1          6.31     overcast clouds
# 2         14.09           clear sky
# 3          8.77           clear sky
# 4          7.99       broken clouds
# ..          ...                 ...
# 688       18.66          few clouds
# 689        6.82    scattered clouds
# 690       13.40           clear sky
# 691        1.79     overcast clouds
# 692        2.17       moderate rain
#
# [693 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
